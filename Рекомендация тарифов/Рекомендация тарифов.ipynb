# %% [markdown]
# ## 1. Изучаем данные

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv ('/datasets/users_behavior.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3214 entries, 0 to 3213
# Data columns (total 5 columns):
# calls       3214 non-null float64
# minutes     3214 non-null float64
# messages    3214 non-null float64
# mb_used     3214 non-null float64
# is_ultra    3214 non-null int64
# dtypes: float64(4), int64(1)
# memory usage: 125.7 KB

# %%
df.head()
# Out:
#    calls  minutes  messages   mb_used  is_ultra
# 0   40.0   311.90      83.0  19915.42         0
# 1   85.0   516.75      56.0  22696.96         0
# 2   77.0   467.66      86.0  21060.45         0
# 3  106.0   745.53      81.0   8437.39         1
# 4   66.0   418.74       1.0  14502.75         0

# %%
df.shape
# Out:
# (3214, 5)

# %% [markdown]
# #### За целевой признак примем значения столбца is_ultra и будем предсказывать его по остальным признакам.

# %% [markdown]
# ## 2. Разбиваем данные на выборки

# %%
df_train, df_valid = train_test_split(df, test_size=0.40, random_state = 42)

# %%
features_train = df_train.drop ('is_ultra', axis=1)
display(features_train.shape)
target_train = df_train['is_ultra']
display(target_train.shape)
# Out:
# (1928, 4)
# (1928,)

# %%
df_valid, df_test = train_test_split(df_valid, test_size=0.50, random_state = 42)

# %%
features_valid = df_valid.drop ('is_ultra', axis=1)
display(features_valid.shape)
target_valid = df_valid['is_ultra']
display(target_valid.shape)
# Out:
# (643, 4)
# (643,)

# %%
features_test = df_test.drop ('is_ultra', axis=1)
display(features_test.shape)
target_test = df_test['is_ultra']
display(target_test.shape)
# Out:
# (643, 4)
# (643,)

# %% [markdown]
# ## 3. Исследуем модели

# %% [markdown]
# #### Исследуем модель классификатора Дерева решений

# %%
for depth in range (1, 11):
    model = DecisionTreeClassifier(random_state = 42, max_depth = depth)
    model.fit(features_train, target_train)
    predict = model.predict(features_valid)
    predict_train = model.predict(features_train)
    accuracy = accuracy_score(target_valid, predict)
    accuracy_train = accuracy_score(target_train, predict_train)
    print("На обучающей выборке")
    print('Глубина:',depth, 'Точность предсказаний:', accuracy_train)
    print("На валидационной выборке")
    print('Глубина:',depth, 'Точность предсказаний:', accuracy)
# Out:
# На обучающей выборке
# Глубина: 1 Точность предсказаний: 0.7479253112033195
# На валидационной выборке
# Глубина: 1 Точность предсказаний: 0.7309486780715396
# На обучающей выборке
# Глубина: 2 Точность предсказаний: 0.7816390041493776
# На валидационной выборке
# Глубина: 2 Точность предсказаний: 0.7822706065318819
# На обучающей выборке
# Глубина: 3 Точность предсказаний: 0.7971991701244814
# На валидационной выборке
# Глубина: 3 Точность предсказаний: 0.7916018662519441
# На обучающей выборке
# Глубина: 4 Точность предсказаний: 0.8086099585062241
# На валидационной выборке
# Глубина: 4 Точность предсказаний: 0.7807153965785381
# На обучающей выборке
# Глубина: 5 Точность предсказаний: 0.8153526970954357
# На валидационной выборке
# Глубина: 5 Точность предсказаний: 0.7729393468118196
# На обучающей выборке
# Глубина: 6 Точность предсказаний: 0.8226141078838174
# На валидационной выборке
# Глубина: 6 Точность предсказаний: 0.776049766718507
# На обучающей выборке
# Глубина: 7 Точность предсказаний: 0.8386929460580913
# На валидационной выборке
# Глубина: 7 Точность предсказаний: 0.7807153965785381
# На обучающей выборке
# Глубина: 8 Точность предсказаний: 0.8521784232365145
# На валидационной выборке
# Глубина: 8 Точность предсказаний: 0.7962674961119751
# На обучающей выборке
# Глубина: 9 Точность предсказаний: 0.8635892116182573
# На валидационной выборке
# Глубина: 9 Точность предсказаний: 0.7807153965785381
# На обучающей выборке
# Глубина: 10 Точность предсказаний: 0.8786307053941909
# На валидационной выборке
# Глубина: 10 Точность предсказаний: 0.7947122861586314

# %% [markdown]
# #### Начиная с глубины дерева в 5 модель склонна переобучаться. Самые точные предсказания при глубине дерева = 4.

# %%
predict = model.predict(features_test)
accuracy = accuracy_score(target_test, predict)
print("На тестовой выборке")
print('Глубина:', 4, 'Точность предсказаний:', accuracy)
# Out:
# На тестовой выборке
# Глубина: 4 Точность предсказаний: 0.7947122861586314

# %% [markdown]
# #### Исследуем модель классификатора Случайного леса

# %%
for estimators in range (1, 110, 10):
    for depth in range (1, 33, 3):
        model = RandomForestClassifier(random_state= 42, n_estimators = estimators, max_depth = depth,
                                   n_jobs = -1, min_samples_split = 3)
        model.fit(features_train, target_train)
        predict = model.predict(features_valid)
        predict_train = model.predict(features_train)
        accuracy = accuracy_score(target_valid, predict)
        accuracy_train = accuracy_score(target_train, predict_train)
        print("На обучающей выборке")
        print('Деревьев:',estimators, 'Глубина:', depth, 'Точность предсказаний:', accuracy_train)
        print("На валидационной выборке")
        print('Деревьев:',estimators, 'Глубина:', depth, 'Точность предсказаний:', accuracy)
# Out:
# На обучающей выборке
# Деревьев: 1 Глубина: 1 Точность предсказаний: 0.7453319502074689
# На валидационной выборке
# Деревьев: 1 Глубина: 1 Точность предсказаний: 0.7558320373250389
# На обучающей выборке
# Деревьев: 1 Глубина: 4 Точность предсказаний: 0.8013485477178424
# На валидационной выборке
# Деревьев: 1 Глубина: 4 Точность предсказаний: 0.7978227060653188
# На обучающей выборке
# Деревьев: 1 Глубина: 7 Точность предсказаний: 0.8267634854771784
# На валидационной выборке
# Деревьев: 1 Глубина: 7 Точность предсказаний: 0.7978227060653188
# На обучающей выборке
# Деревьев: 1 Глубина: 10 Точность предсказаний: 0.845954356846473
# На валидационной выборке
# Деревьев: 1 Глубина: 10 Точность предсказаний: 0.7807153965785381
# На обучающей выборке
# Деревьев: 1 Глубина: 13 Точность предсказаний: 0.8589211618257261
# На валидационной выборке
# Деревьев: 1 Глубина: 13 Точность предсказаний: 0.7465007776049767
# На обучающей выборке
# Деревьев: 1 Глубина: 16 Точность предсказаний: 0.8796680497925311
# На валидационной выборке
# Деревьев: 1 Глубина: 16 Точность предсказаний: 0.7433903576982893
# На обучающей выборке
# Деревьев: 1 Глубина: 19 Точность предсказаний: 0.8848547717842323
# На валидационной выборке
# Деревьев: 1 Глубина: 19 Точность предсказаний: 0.7558320373250389
# На обучающей выборке
# Деревьев: 1 Глубина: 22 Точность предсказаний: 0.8827800829875518
# На валидационной выборке
# Деревьев: 1 Глубина: 22 Точность предсказаний: 0.7698289269051322
# На обучающей выборке
# Деревьев: 1 Глубина: 25 Точность предсказаний: 0.8827800829875518
# На валидационной выборке
# Деревьев: 1 Глубина: 25 Точность предсказаний: 0.7698289269051322
# На обучающей выборке
# Деревьев: 1 Глубина: 28 Точность предсказаний: 0.8827800829875518
# На валидационной выборке
# Деревьев: 1 Глубина: 28 Точность предсказаний: 0.7698289269051322
# На обучающей выборке
# Деревьев: 1 Глубина: 31 Точность предсказаний: 0.8827800829875518
# На валидационной выборке
# Деревьев: 1 Глубина: 31 Точность предсказаний: 0.7698289269051322
# На обучающей выборке
# Деревьев: 11 Глубина: 1 Точность предсказаний: 0.7505186721991701
# На валидационной выборке
# Деревьев: 11 Глубина: 1 Точность предсказаний: 0.7371695178849145
# На обучающей выборке
# Деревьев: 11 Глубина: 4 Точность предсказаний: 0.8122406639004149
# На валидационной выборке
# Деревьев: 11 Глубина: 4 Точность предсказаний: 0.7993779160186625
# На обучающей выборке
# Деревьев: 11 Глубина: 7 Точность предсказаний: 0.8511410788381742
# На валидационной выборке
# Деревьев: 11 Глубина: 7 Точность предсказаний: 0.7978227060653188
# На обучающей выборке
# Деревьев: 11 Глубина: 10 Точность предсказаний: 0.8843360995850622
# На валидационной выборке
# Деревьев: 11 Глубина: 10 Точность предсказаний: 0.7884914463452566
# На обучающей выборке
# Деревьев: 11 Глубина: 13 Точность предсказаний: 0.9175311203319502
# На валидационной выборке
# Деревьев: 11 Глубина: 13 Точность предсказаний: 0.807153965785381
# На обучающей выборке
# Деревьев: 11 Глубина: 16 Точность предсказаний: 0.9429460580912863
# На валидационной выборке
# Деревьев: 11 Глубина: 16 Точность предсказаний: 0.80248833592535
# На обучающей выборке
# Деревьев: 11 Глубина: 19 Точность предсказаний: 0.9678423236514523
# На валидационной выборке
# Деревьев: 11 Глубина: 19 Точность предсказаний: 0.7993779160186625
# На обучающей выборке
# Деревьев: 11 Глубина: 22 Точность предсказаний: 0.975103734439834
# На валидационной выборке
# Деревьев: 11 Глубина: 22 Точность предсказаний: 0.7916018662519441
# На обучающей выборке
# Деревьев: 11 Глубина: 25 Точность предсказаний: 0.9756224066390041
# На валидационной выборке
# Деревьев: 11 Глубина: 25 Точность предсказаний: 0.8009331259720062
# На обучающей выборке
# Деревьев: 11 Глубина: 28 Точность предсказаний: 0.975103734439834
# На валидационной выборке
# Деревьев: 11 Глубина: 28 Точность предсказаний: 0.80248833592535
# На обучающей выборке
# Деревьев: 11 Глубина: 31 Точность предсказаний: 0.975103734439834
# На валидационной выборке
# Деревьев: 11 Глубина: 31 Точность предсказаний: 0.80248833592535
# На обучающей выборке
# Деревьев: 21 Глубина: 1 Точность предсказаний: 0.7515560165975104
# На валидационной выборке
# Деревьев: 21 Глубина: 1 Точность предсказаний: 0.7402799377916018
# На обучающей выборке
# Деревьев: 21 Глубина: 4 Точность предсказаний: 0.8101659751037344
# На валидационной выборке
# Деревьев: 21 Глубина: 4 Точность предсказаний: 0.7916018662519441
# На обучающей выборке
# Деревьев: 21 Глубина: 7 Точность предсказаний: 0.8480290456431535
# На валидационной выборке
# Деревьев: 21 Глубина: 7 Точность предсказаний: 0.7978227060653188
# На обучающей выборке
# Деревьев: 21 Глубина: 10 Точность предсказаний: 0.8817427385892116
# На валидационной выборке
# Деревьев: 21 Глубина: 10 Точность предсказаний: 0.7947122861586314
# На обучающей выборке
# Деревьев: 21 Глубина: 13 Точность предсказаний: 0.9164937759336099
# На валидационной выборке
# Деревьев: 21 Глубина: 13 Точность предсказаний: 0.7978227060653188
# На обучающей выборке
# Деревьев: 21 Глубина: 16 Точность предсказаний: 0.9470954356846473
# На валидационной выборке
# Деревьев: 21 Глубина: 16 Точность предсказаний: 0.7884914463452566
# На обучающей выборке
# Деревьев: 21 Глубина: 19 Точность предсказаний: 0.9756224066390041
# На валидационной выборке
# Деревьев: 21 Глубина: 19 Точность предсказаний: 0.7931570762052877
# На обучающей выборке
# Деревьев: 21 Глубина: 22 Точность предсказаний: 0.983402489626556
# На валидационной выборке
# Деревьев: 21 Глубина: 22 Точность предсказаний: 0.80248833592535
# На обучающей выборке
# Деревьев: 21 Глубина: 25 Точность предсказаний: 0.9844398340248963
# На валидационной выборке
# Деревьев: 21 Глубина: 25 Точность предсказаний: 0.8009331259720062
# На обучающей выборке
# Деревьев: 21 Глубина: 28 Точность предсказаний: 0.9844398340248963
# На валидационной выборке
# Деревьев: 21 Глубина: 28 Точность предсказаний: 0.807153965785381
# На обучающей выборке
# Деревьев: 21 Глубина: 31 Точность предсказаний: 0.9844398340248963
# На валидационной выборке
# Деревьев: 21 Глубина: 31 Точность предсказаний: 0.807153965785381
# На обучающей выборке
# Деревьев: 31 Глубина: 1 Точность предсказаний: 0.7515560165975104
# На валидационной выборке
# Деревьев: 31 Глубина: 1 Точность предсказаний: 0.7371695178849145
# На обучающей выборке
# Деревьев: 31 Глубина: 4 Точность предсказаний: 0.8096473029045643
# На валидационной выборке
# Деревьев: 31 Глубина: 4 Точность предсказаний: 0.7900466562986003
# На обучающей выборке
# Деревьев: 31 Глубина: 7 Точность предсказаний: 0.8480290456431535
# На валидационной выборке
# Деревьев: 31 Глубина: 7 Точность предсказаний: 0.7931570762052877
# На обучающей выборке
# Деревьев: 31 Глубина: 10 Точность предсказаний: 0.8801867219917012
# На валидационной выборке
# Деревьев: 31 Глубина: 10 Точность предсказаний: 0.7962674961119751
# На обучающей выборке
# Деревьев: 31 Глубина: 13 Точность предсказаний: 0.91701244813278
# На валидационной выборке
# Деревьев: 31 Глубина: 13 Точность предсказаний: 0.8009331259720062
# На обучающей выборке
# Деревьев: 31 Глубина: 16 Точность предсказаний: 0.9507261410788381
# На валидационной выборке
# Деревьев: 31 Глубина: 16 Точность предсказаний: 0.7993779160186625
# На обучающей выборке
# Деревьев: 31 Глубина: 19 Точность предсказаний: 0.979253112033195
# На валидационной выборке
# Деревьев: 31 Глубина: 19 Точность предсказаний: 0.8009331259720062
# На обучающей выборке
# Деревьев: 31 Глубина: 22 Точность предсказаний: 0.9859958506224067
# На валидационной выборке
# Деревьев: 31 Глубина: 22 Точность предсказаний: 0.7993779160186625
# На обучающей выборке
# Деревьев: 31 Глубина: 25 Точность предсказаний: 0.9859958506224067
# На валидационной выборке
# Деревьев: 31 Глубина: 25 Точность предсказаний: 0.80248833592535
# На обучающей выборке
# Деревьев: 31 Глубина: 28 Точность предсказаний: 0.9865145228215768
# На валидационной выборке
# Деревьев: 31 Глубина: 28 Точность предсказаний: 0.8040435458786936
# На обучающей выборке
# Деревьев: 31 Глубина: 31 Точность предсказаний: 0.9865145228215768
# На валидационной выборке
# Деревьев: 31 Глубина: 31 Точность предсказаний: 0.8040435458786936
# На обучающей выборке
# Деревьев: 41 Глубина: 1 Точность предсказаний: 0.7505186721991701
# На валидационной выборке
# Деревьев: 41 Глубина: 1 Точность предсказаний: 0.7371695178849145
# На обучающей выборке
# Деревьев: 41 Глубина: 4 Точность предсказаний: 0.8091286307053942
# На валидационной выборке
# Деревьев: 41 Глубина: 4 Точность предсказаний: 0.7900466562986003
# На обучающей выборке
# Деревьев: 41 Глубина: 7 Точность предсказаний: 0.8495850622406639
# На валидационной выборке
# Деревьев: 41 Глубина: 7 Точность предсказаний: 0.7978227060653188
# На обучающей выборке
# Деревьев: 41 Глубина: 10 Точность предсказаний: 0.8796680497925311
# На валидационной выборке
# Деревьев: 41 Глубина: 10 Точность предсказаний: 0.807153965785381
# На обучающей выборке
# Деревьев: 41 Глубина: 13 Точность предсказаний: 0.91701244813278
# На валидационной выборке
# Деревьев: 41 Глубина: 13 Точность предсказаний: 0.8040435458786936
# На обучающей выборке
# Деревьев: 41 Глубина: 16 Точность предсказаний: 0.9517634854771784
# На валидационной выборке
# Деревьев: 41 Глубина: 16 Точность предсказаний: 0.7978227060653188
# На обучающей выборке
# Деревьев: 41 Глубина: 19 Точность предсказаний: 0.9802904564315352
# На валидационной выборке
# Деревьев: 41 Глубина: 19 Точность предсказаний: 0.7993779160186625
# На обучающей выборке
# Деревьев: 41 Глубина: 22 Точность предсказаний: 0.9896265560165975
# На валидационной выборке
# Деревьев: 41 Глубина: 22 Точность предсказаний: 0.7962674961119751
# На обучающей выборке
# Деревьев: 41 Глубина: 25 Точность предсказаний: 0.991701244813278
# На валидационной выборке
# Деревьев: 41 Глубина: 25 Точность предсказаний: 0.80248833592535
# На обучающей выборке
# Деревьев: 41 Глубина: 28 Точность предсказаний: 0.9922199170124482
# На валидационной выборке
# Деревьев: 41 Глубина: 28 Точность предсказаний: 0.8055987558320373
# На обучающей выборке
# Деревьев: 41 Глубина: 31 Точность предсказаний: 0.9927385892116183
# На валидационной выборке
# Деревьев: 41 Глубина: 31 Точность предсказаний: 0.807153965785381
# На обучающей выборке
# Деревьев: 51 Глубина: 1 Точность предсказаний: 0.7505186721991701
# На валидационной выборке
# Деревьев: 51 Глубина: 1 Точность предсказаний: 0.7371695178849145
# На обучающей выборке
# Деревьев: 51 Глубина: 4 Точность предсказаний: 0.8086099585062241
# На валидационной выборке
# Деревьев: 51 Глубина: 4 Точность предсказаний: 0.7900466562986003
# На обучающей выборке
# Деревьев: 51 Глубина: 7 Точность предсказаний: 0.8480290456431535
# На валидационной выборке
# Деревьев: 51 Глубина: 7 Точность предсказаний: 0.7962674961119751
# На обучающей выборке
# Деревьев: 51 Глубина: 10 Точность предсказаний: 0.8796680497925311
# На валидационной выборке
# Деревьев: 51 Глубина: 10 Точность предсказаний: 0.8055987558320373
# На обучающей выборке
# Деревьев: 51 Глубина: 13 Точность предсказаний: 0.9144190871369294
# На валидационной выборке
# Деревьев: 51 Глубина: 13 Точность предсказаний: 0.8118195956454122
# На обучающей выборке
# Деревьев: 51 Глубина: 16 Точность предсказаний: 0.9491701244813278
# На валидационной выборке
# Деревьев: 51 Глубина: 16 Точность предсказаний: 0.80248833592535
# На обучающей выборке
# Деревьев: 51 Глубина: 19 Точность предсказаний: 0.9808091286307054
# На валидационной выборке
# Деревьев: 51 Глубина: 19 Точность предсказаний: 0.8009331259720062
# На обучающей выборке
# Деревьев: 51 Глубина: 22 Точность предсказаний: 0.991701244813278
# На валидационной выборке
# Деревьев: 51 Глубина: 22 Точность предсказаний: 0.8009331259720062
# На обучающей выборке
# Деревьев: 51 Глубина: 25 Точность предсказаний: 0.9927385892116183
# На валидационной выборке
# Деревьев: 51 Глубина: 25 Точность предсказаний: 0.8133748055987559
# На обучающей выборке
# Деревьев: 51 Глубина: 28 Точность предсказаний: 0.9932572614107884
# На валидационной выборке
# Деревьев: 51 Глубина: 28 Точность предсказаний: 0.8055987558320373
# На обучающей выборке
# Деревьев: 51 Глубина: 31 Точность предсказаний: 0.9927385892116183
# На валидационной выборке
# Деревьев: 51 Глубина: 31 Точность предсказаний: 0.8055987558320373
# На обучающей выборке
# Деревьев: 61 Глубина: 1 Точность предсказаний: 0.7494813278008299
# На валидационной выборке
# Деревьев: 61 Глубина: 1 Точность предсказаний: 0.7387247278382582
# На обучающей выборке
# Деревьев: 61 Глубина: 4 Точность предсказаний: 0.8075726141078838
# На валидационной выборке
# Деревьев: 61 Глубина: 4 Точность предсказаний: 0.7884914463452566
# На обучающей выборке
# Деревьев: 61 Глубина: 7 Точность предсказаний: 0.8511410788381742
# На валидационной выборке
# Деревьев: 61 Глубина: 7 Точность предсказаний: 0.7962674961119751
# На обучающей выборке
# Деревьев: 61 Глубина: 10 Точность предсказаний: 0.8807053941908713
# На валидационной выборке
# Деревьев: 61 Глубина: 10 Точность предсказаний: 0.8055987558320373
# На обучающей выборке
# Деревьев: 61 Глубина: 13 Точность предсказаний: 0.9107883817427386
# На валидационной выборке
# Деревьев: 61 Глубина: 13 Точность предсказаний: 0.8133748055987559
# На обучающей выборке
# Деревьев: 61 Глубина: 16 Точность предсказаний: 0.9496887966804979
# На валидационной выборке
# Деревьев: 61 Глубина: 16 Точность предсказаний: 0.80248833592535
# На обучающей выборке
# Деревьев: 61 Глубина: 19 Точность предсказаний: 0.9823651452282157
# На валидационной выборке
# Деревьев: 61 Глубина: 19 Точность предсказаний: 0.7978227060653188
# На обучающей выборке
# Деревьев: 61 Глубина: 22 Точность предсказаний: 0.9922199170124482
# На валидационной выборке
# Деревьев: 61 Глубина: 22 Точность предсказаний: 0.7947122861586314
# На обучающей выборке
# Деревьев: 61 Глубина: 25 Точность предсказаний: 0.9937759336099585
# На валидационной выборке
# Деревьев: 61 Глубина: 25 Точность предсказаний: 0.807153965785381
# На обучающей выборке
# Деревьев: 61 Глубина: 28 Точность предсказаний: 0.9948132780082988
# На валидационной выборке
# Деревьев: 61 Глубина: 28 Точность предсказаний: 0.8055987558320373
# На обучающей выборке
# Деревьев: 61 Глубина: 31 Точность предсказаний: 0.9942946058091287
# На валидационной выборке
# Деревьев: 61 Глубина: 31 Точность предсказаний: 0.8055987558320373
# На обучающей выборке
# Деревьев: 71 Глубина: 1 Точность предсказаний: 0.7505186721991701
# На валидационной выборке
# Деревьев: 71 Глубина: 1 Точность предсказаний: 0.7387247278382582
# На обучающей выборке
# Деревьев: 71 Глубина: 4 Точность предсказаний: 0.8075726141078838
# На валидационной выборке
# Деревьев: 71 Глубина: 4 Точность предсказаний: 0.7884914463452566
# На обучающей выборке
# Деревьев: 71 Глубина: 7 Точность предсказаний: 0.8516597510373444
# На валидационной выборке
# Деревьев: 71 Глубина: 7 Точность предсказаний: 0.7993779160186625
# На обучающей выборке
# Деревьев: 71 Глубина: 10 Точность предсказаний: 0.8812240663900415
# На валидационной выборке
# Деревьев: 71 Глубина: 10 Точность предсказаний: 0.8055987558320373
# На обучающей выборке
# Деревьев: 71 Глубина: 13 Точность предсказаний: 0.9123443983402489
# На валидационной выборке
# Деревьев: 71 Глубина: 13 Точность предсказаний: 0.8040435458786936
# На обучающей выборке
# Деревьев: 71 Глубина: 16 Точность предсказаний: 0.9507261410788381
# На валидационной выборке
# Деревьев: 71 Глубина: 16 Точность предсказаний: 0.8055987558320373
# На обучающей выборке
# Деревьев: 71 Глубина: 19 Точность предсказаний: 0.9839211618257261
# На валидационной выборке
# Деревьев: 71 Глубина: 19 Точность предсказаний: 0.8040435458786936
# На обучающей выборке
# Деревьев: 71 Глубина: 22 Точность предсказаний: 0.9942946058091287
# На валидационной выборке
# Деревьев: 71 Глубина: 22 Точность предсказаний: 0.8040435458786936
# На обучающей выборке
# Деревьев: 71 Глубина: 25 Точность предсказаний: 0.9953319502074689
# На валидационной выборке
# Деревьев: 71 Глубина: 25 Точность предсказаний: 0.807153965785381
# На обучающей выборке
# Деревьев: 71 Глубина: 28 Точность предсказаний: 0.995850622406639
# На валидационной выборке
# Деревьев: 71 Глубина: 28 Точность предсказаний: 0.8055987558320373
# На обучающей выборке
# Деревьев: 71 Глубина: 31 Точность предсказаний: 0.9963692946058091
# На валидационной выборке
# Деревьев: 71 Глубина: 31 Точность предсказаний: 0.807153965785381
# На обучающей выборке
# Деревьев: 81 Глубина: 1 Точность предсказаний: 0.7505186721991701
# На валидационной выборке
# Деревьев: 81 Глубина: 1 Точность предсказаний: 0.7387247278382582
# На обучающей выборке
# Деревьев: 81 Глубина: 4 Точность предсказаний: 0.8075726141078838
# На валидационной выборке
# Деревьев: 81 Глубина: 4 Точность предсказаний: 0.7884914463452566
# На обучающей выборке
# Деревьев: 81 Глубина: 7 Точность предсказаний: 0.8521784232365145
# На валидационной выборке
# Деревьев: 81 Глубина: 7 Точность предсказаний: 0.7978227060653188
# На обучающей выборке
# Деревьев: 81 Глубина: 10 Точность предсказаний: 0.8796680497925311
# На валидационной выборке
# Деревьев: 81 Глубина: 10 Точность предсказаний: 0.8087091757387247
# На обучающей выборке
# Деревьев: 81 Глубина: 13 Точность предсказаний: 0.9123443983402489
# На валидационной выборке
# Деревьев: 81 Глубина: 13 Точность предсказаний: 0.8040435458786936
# На обучающей выборке
# Деревьев: 81 Глубина: 16 Точность предсказаний: 0.9512448132780082
# На валидационной выборке
# Деревьев: 81 Глубина: 16 Точность предсказаний: 0.807153965785381
# На обучающей выборке
# Деревьев: 81 Глубина: 19 Точность предсказаний: 0.9823651452282157
# На валидационной выборке
# Деревьев: 81 Глубина: 19 Точность предсказаний: 0.8055987558320373
# На обучающей выборке
# Деревьев: 81 Глубина: 22 Точность предсказаний: 0.9937759336099585
# На валидационной выборке
# Деревьев: 81 Глубина: 22 Точность предсказаний: 0.8040435458786936
# На обучающей выборке
# Деревьев: 81 Глубина: 25 Точность предсказаний: 0.9968879668049793
# На валидационной выборке
# Деревьев: 81 Глубина: 25 Точность предсказаний: 0.807153965785381
# На обучающей выборке
# Деревьев: 81 Глубина: 28 Точность предсказаний: 0.9979253112033195
# На валидационной выборке
# Деревьев: 81 Глубина: 28 Точность предсказаний: 0.807153965785381
# На обучающей выборке
# Деревьев: 81 Глубина: 31 Точность предсказаний: 0.9979253112033195
# На валидационной выборке
# Деревьев: 81 Глубина: 31 Точность предсказаний: 0.807153965785381
# На обучающей выборке
# Деревьев: 91 Глубина: 1 Точность предсказаний: 0.75
# На валидационной выборке
# Деревьев: 91 Глубина: 1 Точность предсказаний: 0.7387247278382582
# На обучающей выборке
# Деревьев: 91 Глубина: 4 Точность предсказаний: 0.8075726141078838
# На валидационной выборке
# Деревьев: 91 Глубина: 4 Точность предсказаний: 0.7900466562986003
# На обучающей выборке
# Деревьев: 91 Глубина: 7 Точность предсказаний: 0.850103734439834
# На валидационной выборке
# Деревьев: 91 Глубина: 7 Точность предсказаний: 0.7993779160186625
# На обучающей выборке
# Деревьев: 91 Глубина: 10 Точность предсказаний: 0.8786307053941909
# На валидационной выборке
# Деревьев: 91 Глубина: 10 Точность предсказаний: 0.807153965785381
# На обучающей выборке
# Деревьев: 91 Глубина: 13 Точность предсказаний: 0.9128630705394191
# На валидационной выборке
# Деревьев: 91 Глубина: 13 Точность предсказаний: 0.8040435458786936
# На обучающей выборке
# Деревьев: 91 Глубина: 16 Точность предсказаний: 0.9522821576763485
# На валидационной выборке
# Деревьев: 91 Глубина: 16 Точность предсказаний: 0.8102643856920684
# На обучающей выборке
# Деревьев: 91 Глубина: 19 Точность предсказаний: 0.9828838174273858
# На валидационной выборке
# Деревьев: 91 Глубина: 19 Точность предсказаний: 0.8087091757387247
# На обучающей выборке
# Деревьев: 91 Глубина: 22 Точность предсказаний: 0.9953319502074689
# На валидационной выборке
# Деревьев: 91 Глубина: 22 Точность предсказаний: 0.8009331259720062
# На обучающей выборке
# Деревьев: 91 Глубина: 25 Точность предсказаний: 0.9984439834024896
# На валидационной выборке
# Деревьев: 91 Глубина: 25 Точность предсказаний: 0.8055987558320373
# На обучающей выборке
# Деревьев: 91 Глубина: 28 Точность предсказаний: 0.9989626556016598
# На валидационной выборке
# Деревьев: 91 Глубина: 28 Точность предсказаний: 0.8040435458786936
# На обучающей выборке
# Деревьев: 91 Глубина: 31 Точность предсказаний: 0.9989626556016598
# На валидационной выборке
# Деревьев: 91 Глубина: 31 Точность предсказаний: 0.8009331259720062
# На обучающей выборке
# Деревьев: 101 Глубина: 1 Точность предсказаний: 0.75
# На валидационной выборке
# Деревьев: 101 Глубина: 1 Точность предсказаний: 0.7387247278382582
# На обучающей выборке
# Деревьев: 101 Глубина: 4 Точность предсказаний: 0.8075726141078838
# На валидационной выборке
# Деревьев: 101 Глубина: 4 Точность предсказаний: 0.7900466562986003
# На обучающей выборке
# Деревьев: 101 Глубина: 7 Точность предсказаний: 0.8506224066390041
# На валидационной выборке
# Деревьев: 101 Глубина: 7 Точность предсказаний: 0.7978227060653188
# На обучающей выборке
# Деревьев: 101 Глубина: 10 Точность предсказаний: 0.8807053941908713
# На валидационной выборке
# Деревьев: 101 Глубина: 10 Точность предсказаний: 0.8055987558320373
# На обучающей выборке
# Деревьев: 101 Глубина: 13 Точность предсказаний: 0.9133817427385892
# На валидационной выборке
# Деревьев: 101 Глубина: 13 Точность предсказаний: 0.8040435458786936
# На обучающей выборке
# Деревьев: 101 Глубина: 16 Точность предсказаний: 0.950207468879668
# На валидационной выборке
# Деревьев: 101 Глубина: 16 Точность предсказаний: 0.807153965785381
# На обучающей выборке
# Деревьев: 101 Глубина: 19 Точность предсказаний: 0.9818464730290456
# На валидационной выборке
# Деревьев: 101 Глубина: 19 Точность предсказаний: 0.8055987558320373
# На обучающей выборке
# Деревьев: 101 Глубина: 22 Точность предсказаний: 0.9968879668049793
# На валидационной выборке
# Деревьев: 101 Глубина: 22 Точность предсказаний: 0.7993779160186625
# На обучающей выборке
# Деревьев: 101 Глубина: 25 Точность предсказаний: 0.9989626556016598
# На валидационной выборке
# Деревьев: 101 Глубина: 25 Точность предсказаний: 0.80248833592535
# На обучающей выборке
# Деревьев: 101 Глубина: 28 Точность предсказаний: 0.9989626556016598
# На валидационной выборке
# Деревьев: 101 Глубина: 28 Точность предсказаний: 0.80248833592535
# На обучающей выборке
# Деревьев: 101 Глубина: 31 Точность предсказаний: 0.9989626556016598
# На валидационной выборке
# Деревьев: 101 Глубина: 31 Точность предсказаний: 0.80248833592535

# %%
model_winner = RandomForestClassifier(random_state= 42, n_estimators = 11, max_depth = 13,
                                   n_jobs = -1, min_samples_split = 3)
model_winner.fit(features_train, target_train)
predict = model_winner.predict(features_valid)
predict_train = model_winner.predict(features_train)
accuracy = accuracy_score(target_valid, predict)
accuracy_train = accuracy_score(target_train, predict_train)
print("На обучающей выборке")
print('Деревьев:',11, 'Глубина:', 13, 'Точность предсказаний:', accuracy_train)
print("На тестовой выборке")
print('Деревьев:',11, 'Глубина:', 13, 'Точность предсказаний:', accuracy)
# Out:
# На обучающей выборке
# Деревьев: 11 Глубина: 13 Точность предсказаний: 0.9175311203319502
# На тестовой выборке
# Деревьев: 11 Глубина: 13 Точность предсказаний: 0.807153965785381

# %% [markdown]
# #### Как видно, модель начинает переобучаться как при большом количестве деревьев и малой глубине, так и наоборот при малом количестве деревьев и большой глубине. На мой взгляд лучшим сочетанием количества деревьев и их глубины являются   11 деревьев с глубиной 13. Модель несколько переобучена, но при этом начинает показывать максимально точные предсказания.
# Гиперпараметром n_jobs мы задействовали все ядра процессора для ускорения обучения модели.
# - На обучающей выборке
# - Деревьев: 11 Глубина: 13 Точность предсказаний: 0.9175311203319502
# - На тестовой выборке
# - Деревьев: 11 Глубина: 13 Точность предсказаний: 0.807153965785381

# %% [markdown]
# #### Исследуем модель классификатора Логистической регрессии

# %%
model = LogisticRegression(random_state = 42, solver='lbfgs')
model.fit(features_train, target_train)
accuracy = model.score(features_valid, target_valid)
accuracy_t = model.score(features_test, target_test)
print('Точность предсказаний на валидационной выборке:', accuracy)
print('Точность предсказаний на тестовой выборке:', accuracy_t)
# Out:
# Точность предсказаний на валидационной выборке: 0.7402799377916018
# Точность предсказаний на тестовой выборке: 0.7682737169517885
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)

# %% [markdown]
# #### Данная модель в условиях конкретной задачи оказалась наименее точной в своих предсказаниях, хотя она и выигрывает в скорости

# %% [markdown]
# ## 4. Проверка модели на тестовой выборке

# %% [markdown]
# #### В качестве модели выберем модель случайного леса, как самую точную

# %%
predict_test = model_winner.predict(features_test)
predict_train = model_winner.predict(features_train)
accuracy_test = accuracy_score(target_test, predict_test)
accuracy_train = accuracy_score(target_train, predict_train)
print("На обучающей выборке")
print('Деревьев:',11, 'Глубина:', 13, 'Точность предсказаний:', accuracy_train)
print("На тестовой выборке")
print('Деревьев:',11, 'Глубина:', 13, 'Точность предсказаний:', accuracy_test)
# Out:
# На обучающей выборке
# Деревьев: 11 Глубина: 13 Точность предсказаний: 0.9175311203319502
# На тестовой выборке
# Деревьев: 11 Глубина: 13 Точность предсказаний: 0.8118195956454122

# %% [markdown]
# ### Вывод:
# - самой точной из представленных моделей является модель случайного леса, показавшая прирост производительности по сравнению с деревом решений на 1.3% и по сравнению с логистической моделью на 3.9% на тестовой выборке;
# - данная модель менее склонна к переобучению, чем дерево решений;
# - из минусов - это медленная скорость работы по сравнению с остальными.
# Если точность в 3.9% не является критичной, в отличае от скорости работы, то можно использовать логистическую регрессию

# %% [markdown]
# ## 5. Проверяем модели на адекватность

# %%
target = df['is_ultra']
predictions = pd.Series(target.mean(), index=target.index)
mse = mean_squared_error(target, predictions)
rmse = mse**0.5
print('RMSE:', rmse)
# Out:
# RMSE: 0.46102797293043907

# %% [markdown]
# #### Вывод:
# - корень из среднеквадратичной ошибки нашей 'случайной модели' 0.46, что соответствует 46% слепых угадываний. Провереные нами модели показали эфективность от 71%, что считаю успешным экспериментом.
# - адекватность наших моделей доказана.

# %% [markdown]
# #### Воспользуемся DummyClassifier со стратегией случайного предсказания для создания упрощенной модели предсказания

# %%
from sklearn.dummy import DummyClassifier

# %%
new = DummyClassifier(strategy="uniform", random_state = 42)
new.fit(features_train, target_train)
print('Точность предсказаний на валидационной выборке:', new.score (features_valid, target_valid))
print('Точность предсказаний на тестовой выборке:', new.score (features_test, target_test))
# Out:
# Точность предсказаний на валидационной выборке: 0.5194401244167963
# Точность предсказаний на тестовой выборке: 0.5101088646967341

# %% [markdown]
# #### Вывод:
# - при создании модели с простыми правилами предсказания на тестовой выборке мы получили точность около 51%, что доказывает, что слепые предсказания в данном конкретном случае имеют ~50% шанс на угадывание тарифа;
# - Все из представленых нами моделей по эффективности превосходят этот показатель всреднем на 25%, что доказывает адекватность обученных нами моделей.
